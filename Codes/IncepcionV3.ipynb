# %% [markdown]
# ### Import

# %%
import os
import random
import numpy as np
import collections
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import GroupKFold
from PIL import Image
import re
from torchvision import transforms, models
import copy
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, classification_report
from torchvision.models.inception import InceptionOutputs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Difine Seed

# %%
# Set a fixed seed value for reproducibility
seed = 42

# Set the seed for Python's built-in random module
random.seed(seed)

# Set the seed for NumPy
np.random.seed(seed)

# Set the seed for PyTorch
torch.manual_seed(seed)

# Ensure that the seed is set for CUDA as well if using GPU
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if using multi-GPU

# Additional configuration for determinism
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Data Utils

# %%
class CustomDataset(Dataset):
    def __init__(self, file_paths, labels, transform=None):
        self.file_paths = file_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        file_path = self.file_paths[idx]

        image = Image.open(file_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        label = self.labels[idx]
        return image, label

# Function to extract patient ID from filenames (for k-fold cross validation)
def extract_patient_id(filename):
    match = re.match(r'([\w\s]+-\d+of\d+)', filename)
    if match:
        return match.group(1)
    else:
        raise ValueError(f"Filename {filename} does not match the expected pattern.")

# Function to load data and split into file paths, labels, and patient IDs
def load_data(root_dir, classes):
    file_paths = []
    labels = []
    patient_ids = []

    for class_index, class_name in enumerate(classes):
        class_dir = os.path.join(root_dir, class_name)
        for filename in os.listdir(class_dir):
            file_path = os.path.join(class_dir, filename)
            file_paths.append(file_path)
            labels.append(class_index)
            patient_ids.append(extract_patient_id(filename))

    return file_paths, labels, patient_ids

# Calculate padding
# pad_size = (340 - 240) // 2  # 30 pixels to be padded on each side

# Define transform with padding
transform = transforms.Compose([
    # transforms.Resize((300, 300)),  # First resize to 240x240
    # transforms.Pad(padding=pad_size),  # Then pad to 299x299
    transforms.ToTensor(),
])

# %%
# Define root directory and classes
root_dir = "/content/drive/MyDrive/projects/SecondTry/JPG_480/train"
test_root_dir = "/content/drive/MyDrive/projects/SecondTry/JPG_480/test"
test_root_dir_2 = "/content/drive/MyDrive/projects/SecondTry/JPG_480/val"
classes = ['Good', 'Bad', 'Null']

# Load file paths, labels, and patient IDs
file_paths, labels, patient_ids = load_data(root_dir, classes)
test_file_paths, test_labels, test_patient_ids = load_data(test_root_dir, classes)
test_file_paths_2, test_labels_2, test_patient_ids_2 = load_data(test_root_dir_2, classes)

# %%
# Create a test dataset
test_dataset = CustomDataset(test_file_paths, test_labels, transform=transform)
test_dataset_2 = CustomDataset(test_file_paths_2, test_labels_2, transform=transform)

# Create a DataLoader for the test dataset
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_loader_2 = DataLoader(test_dataset_2, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ### K-Fold

# %%
# Initialize GroupKFold
num_folds = 5
gkf = GroupKFold(n_splits=num_folds)

# %% [markdown]
# ### Model

# %%
class ModifiedInceptionV3(nn.Module):
    def __init__(self, num_classes=1000, dropout_prob=0.5):
        super(ModifiedInceptionV3, self).__init__()
        self.inception = models.inception_v3(pretrained=True)
        self.inception.avgpool = nn.AdaptiveAvgPool2d(1)
        self.inception.fc = nn.Linear(2048, num_classes)  # Modify the final fully connected layer
        self.inception.dropout = nn.Dropout(p=dropout_prob)

        # Add AdaptiveAvgPool2d before the fully connected layers


    def forward(self, x):
        x = self.inception(x)
        return x

# %% [markdown]
# ### Hyperparameter

# %%
fold_results = []  # To store the last validation accuracy of each fold
best_model_per_fold = None  # To store the best model based on the last validation accuracy
best_fold_acc = 0.0  # Track the highest validation accuracy among the last epochs of all folds

num_epochs = 15

# Total number of unique patients across the dataset
total_unique_patients = len(set(patient_ids))

# Define the number of classes
num_classes = len(classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Train Utils

# %%
# Function to train the model for a single epoch
def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)

        # If Inception, we need to handle the auxiliary output
        if isinstance(outputs, InceptionOutputs):
            logits, aux_logits = outputs.logits, outputs.aux_logits
            loss = criterion(logits, labels) + 0.4 * criterion(aux_logits, labels)  # Weighted sum of losses
        else:
            logits = outputs
            loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        _, preds = torch.max(logits, 1)
        correct += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = correct.double() / len(dataloader.dataset)
    return epoch_loss, epoch_acc

# Function to validate the model
def validate_one_epoch(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)

            # If Inception, we need to handle the auxiliary output
            if isinstance(outputs, InceptionOutputs):
                logits = outputs.logits
            else:
                logits = outputs

            loss = criterion(logits, labels)
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(logits, 1)
            correct += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = correct.double() / len(dataloader.dataset)
    return epoch_loss, epoch_acc

# %% [markdown]
# ### Training

# %%
for fold, (train_idx, val_idx) in enumerate(gkf.split(file_paths, labels, groups=patient_ids)):
    print(f'Fold {fold+1}/{num_folds}')

    # Get patient IDs for training and validation sets
    train_patient_ids = [patient_ids[i] for i in train_idx]
    val_patient_ids = [patient_ids[i] for i in val_idx]

    # Check for overlap between training and validation patient IDs
    overlap = set(train_patient_ids) & set(val_patient_ids)
    if overlap:
        print(f"Overlap detected in fold {fold+1}! Overlapping patient IDs: {overlap}")
    else:
        print(f"No overlap between training and validation patient sets in fold {fold+1}.")

    # Calculate the percentage of unique patients in the validation set
    unique_val_patients = len(set(val_patient_ids))
    val_percentage = (unique_val_patients / total_unique_patients) * 100
    print(f'Percentage of patients in validation set for fold {fold+1}: {val_percentage:.2f}%')

    # Create training and validation datasets for this fold
    train_dataset = CustomDataset([file_paths[i] for i in train_idx], [labels[i] for i in train_idx], transform=transform)
    val_dataset = CustomDataset([file_paths[i] for i in val_idx], [labels[i] for i in val_idx], transform=transform)

    # Create dataloaders
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

    # Initialize the model for this fold (reinitialize weights)
    model = ModifiedInceptionV3(num_classes=num_classes, dropout_prob=0.5)
    model = model.to(device)

    # Define optimizer and loss function
    optimizer = optim.SGD(model.parameters(), lr=0.000714, momentum=0.9)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')

        # Train and validate for one epoch
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_loss, val_acc = validate_one_epoch(model, val_loader, criterion, device)

        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')
        print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

    # Save the last validation accuracy of the current fold
    fold_results.append(val_acc.item())

    print(f'Last Validation Accuracy for Fold {fold+1}: {val_acc:.4f}')

    # Track the best model and accuracy among the last validation accuracies
    if val_acc > best_fold_acc:
        best_fold_acc = val_acc
        best_model_per_fold = copy.deepcopy(model.state_dict())  # Store the best model weights

# Calculate the average accuracy across all folds
average_acc = sum(fold_results) / len(fold_results)
print(f'Average Accuracy across all folds: {average_acc:.4f}')

# Print the best validation accuracy among the last validation accuracies
print(f'Best Validation Accuracy among all folds: {best_fold_acc:.4f}')

# Load the best model weights from the fold with the highest last validation accuracy
model.load_state_dict(best_model_per_fold)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Fold 1/5
# No overlap between training and validation patient sets in fold 1.
# Percentage of patients in validation set for fold 1: 20.25%
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:00<00:00, 201MB/s]
# Epoch 1/15
# Train Loss: 2.9503, Train Acc: 0.4054
# Val Loss: 1.0531, Val Acc: 0.4315
# Epoch 2/15
# Train Loss: 1.1872, Train Acc: 0.6060
# Val Loss: 0.9164, Val Acc: 0.5477
# Epoch 3/15
# Train Loss: 0.7303, Train Acc: 0.8046
# Val Loss: 0.6032, Val Acc: 0.7967
# Epoch 4/15
# Train Loss: 0.4211, Train Acc: 0.9179
# Val Loss: 0.4776, Val Acc: 0.8050
# Epoch 5/15
# Train Loss: 0.2404, Train Acc: 0.9657
# Val Loss: 0.3895, Val Acc: 0.8506
# Epoch 6/15
# Train Loss: 0.1849, Train Acc: 0.9709
# Val Loss: 0.3395, Val Acc: 0.8714
# Epoch 7/15
# Train Loss: 0.1364, Train Acc: 0.9844
# Val Loss: 0.3033, Val Acc: 0.8838
# Epoch 8/15
# Train Loss: 0.1036, Train Acc: 0.9865
# Val Loss: 0.3957, Val Acc: 0.8506
# Epoch 9/15
# Train Loss: 0.0486, Train Acc: 0.9948
# Val Loss: 0.2978, Val Acc: 0.8880
# Epoch 10/15
# Train Loss: 0.0451, Train Acc: 0.9958
# Val Loss: 0.2560, Val Acc: 0.9046
# Epoch 11/15
# Train Loss: 0.0267, Train Acc: 0.9990
# Val Loss: 0.2316, Val Acc: 0.9046
# Epoch 12/15
# Train Loss: 0.0254, Train Acc: 0.9979
# Val Loss: 0.2052, Val Acc: 0.9046
# Epoch 13/15
# Train Loss: 0.0200, Train Acc: 0.9969
# Val Loss: 0.2129, Val Acc: 0.9253
# Epoch 14/15
# Train Loss: 0.0241, Train Acc: 0.9990
# Val Loss: 0.2030, Val Acc: 0.9295
# Epoch 15/15
# Train Loss: 0.0241, Train Acc: 0.9979
# Val Loss: 0.2106, Val Acc: 0.9295
# Last Validation Accuracy for Fold 1: 0.9295
# Fold 2/5
# No overlap between training and validation patient sets in fold 2.
# Percentage of patients in validation set for fold 2: 19.63%
# Epoch 1/15
# Train Loss: 2.8958, Train Acc: 0.4341
# Val Loss: 1.0422, Val Acc: 0.4833
# Epoch 2/15
# Train Loss: 1.1622, Train Acc: 0.5805
# Val Loss: 0.8394, Val Acc: 0.6917
# Epoch 3/15
# Train Loss: 0.6650, Train Acc: 0.8442
# Val Loss: 0.5968, Val Acc: 0.7500
# Epoch 4/15
# Train Loss: 0.4112, Train Acc: 0.9055
# Val Loss: 0.4784, Val Acc: 0.8333
# Epoch 5/15
# Train Loss: 0.2234, Train Acc: 0.9730
# Val Loss: 0.4463, Val Acc: 0.8125
# Epoch 6/15
# Train Loss: 0.1546, Train Acc: 0.9823
# Val Loss: 0.5167, Val Acc: 0.8000
# Epoch 7/15
# Train Loss: 0.1003, Train Acc: 0.9917
# Val Loss: 0.5019, Val Acc: 0.8125
# Epoch 8/15
# Train Loss: 0.1211, Train Acc: 0.9823
# Val Loss: 0.4576, Val Acc: 0.7917
# Epoch 9/15
# Train Loss: 0.0588, Train Acc: 0.9948
# Val Loss: 0.3660, Val Acc: 0.8375
# Epoch 10/15
# Train Loss: 0.0462, Train Acc: 0.9958
# Val Loss: 0.5581, Val Acc: 0.8333
# Epoch 11/15
# Train Loss: 0.1015, Train Acc: 0.9844
# Val Loss: 0.5608, Val Acc: 0.8125
# Epoch 12/15
# Train Loss: 0.0667, Train Acc: 0.9907
# Val Loss: 0.4754, Val Acc: 0.8208
# Epoch 13/15
# Train Loss: 0.0301, Train Acc: 0.9969
# Val Loss: 0.5065, Val Acc: 0.8250
# Epoch 14/15
# Train Loss: 0.0395, Train Acc: 0.9938
# Val Loss: 0.6163, Val Acc: 0.8333
# Epoch 15/15
# Train Loss: 0.0825, Train Acc: 0.9761
# Val Loss: 0.6051, Val Acc: 0.8208
# Last Validation Accuracy for Fold 2: 0.8208
# Fold 3/5
# No overlap between training and validation patient sets in fold 3.
# Percentage of patients in validation set for fold 3: 20.25%
# Epoch 1/15
# Train Loss: 2.9879, Train Acc: 0.3621
# Val Loss: 1.0309, Val Acc: 0.4876
# Epoch 2/15
# Train Loss: 1.1660, Train Acc: 0.6056
# Val Loss: 0.8529, Val Acc: 0.6983
# Epoch 3/15
# Train Loss: 0.7617, Train Acc: 0.7419
# Val Loss: 0.5969, Val Acc: 0.7934
# Epoch 4/15
# Train Loss: 0.4861, Train Acc: 0.8762
# Val Loss: 0.4181, Val Acc: 0.8760
# Epoch 5/15
# Train Loss: 0.2695, Train Acc: 0.9542
# Val Loss: 0.3219, Val Acc: 0.9132
# Epoch 6/15
# Train Loss: 0.1513, Train Acc: 0.9844
# Val Loss: 0.2923, Val Acc: 0.8719
# Epoch 7/15
# Train Loss: 0.0947, Train Acc: 0.9906
# Val Loss: 0.2227, Val Acc: 0.9256
# Epoch 8/15
# Train Loss: 0.0563, Train Acc: 0.9969
# Val Loss: 0.2063, Val Acc: 0.9339
# Epoch 9/15
# Train Loss: 0.0452, Train Acc: 0.9969
# Val Loss: 0.2269, Val Acc: 0.9421
# Epoch 10/15
# Train Loss: 0.0441, Train Acc: 0.9979
# Val Loss: 0.2061, Val Acc: 0.9256
# Epoch 11/15
# Train Loss: 0.0413, Train Acc: 0.9969
# Val Loss: 0.2342, Val Acc: 0.9174
# Epoch 12/15
# Train Loss: 0.0335, Train Acc: 0.9958
# Val Loss: 0.2431, Val Acc: 0.9174
# Epoch 13/15
# Train Loss: 0.0290, Train Acc: 0.9958
# Val Loss: 0.2308, Val Acc: 0.9174
# Epoch 14/15
# Train Loss: 0.0259, Train Acc: 0.9969
# Val Loss: 0.2930, Val Acc: 0.8926
# Epoch 15/15
# Train Loss: 0.0206, Train Acc: 0.9990
# Val Loss: 0.1798, Val Acc: 0.9421
# Last Validation Accuracy for Fold 3: 0.9421
# Fold 4/5
# No overlap between training and validation patient sets in fold 4.
# Percentage of patients in validation set for fold 4: 19.63%
# Epoch 1/15
# Train Loss: 2.9411, Train Acc: 0.3925
# Val Loss: 1.0490, Val Acc: 0.4875
# Epoch 2/15
# Train Loss: 1.1428, Train Acc: 0.6397
# Val Loss: 0.8291, Val Acc: 0.7042
# Epoch 3/15
# Train Loss: 0.7391, Train Acc: 0.7954
# Val Loss: 0.5940, Val Acc: 0.7708
# Epoch 4/15
# Train Loss: 0.4626, Train Acc: 0.8930
# Val Loss: 0.4228, Val Acc: 0.8833
# Epoch 5/15
# Train Loss: 0.2758, Train Acc: 0.9429
# Val Loss: 0.4066, Val Acc: 0.8375
# Epoch 6/15
# Train Loss: 0.1665, Train Acc: 0.9740
# Val Loss: 0.3839, Val Acc: 0.8333
# Epoch 7/15
# Train Loss: 0.2049, Train Acc: 0.9595
# Val Loss: 0.2852, Val Acc: 0.8958
# Epoch 8/15
# Train Loss: 0.0948, Train Acc: 0.9823
# Val Loss: 0.2123, Val Acc: 0.9458
# Epoch 9/15
# Train Loss: 0.0598, Train Acc: 0.9948
# Val Loss: 0.3316, Val Acc: 0.8750
# Epoch 10/15
# Train Loss: 0.0522, Train Acc: 0.9917
# Val Loss: 0.3290, Val Acc: 0.8667
# Epoch 11/15
# Train Loss: 0.1682, Train Acc: 0.9626
# Val Loss: 0.4556, Val Acc: 0.8333
# Epoch 12/15
# Train Loss: 0.1318, Train Acc: 0.9699
# Val Loss: 0.2493, Val Acc: 0.9000
# Epoch 13/15
# Train Loss: 0.0940, Train Acc: 0.9865
# Val Loss: 0.3972, Val Acc: 0.8500
# Epoch 14/15
# Train Loss: 0.0965, Train Acc: 0.9813
# Val Loss: 0.2290, Val Acc: 0.8917
# Epoch 15/15
# Train Loss: 0.0411, Train Acc: 0.9938
# Val Loss: 0.2997, Val Acc: 0.8750
# Last Validation Accuracy for Fold 4: 0.8750
# Fold 5/5
# No overlap between training and validation patient sets in fold 5.
# Percentage of patients in validation set for fold 5: 20.25%
# Epoch 1/15
# Train Loss: 2.8986, Train Acc: 0.4444
# Val Loss: 1.0649, Val Acc: 0.4458
# Epoch 2/15
# Train Loss: 1.0833, Train Acc: 0.6490
# Val Loss: 0.8465, Val Acc: 0.6875
# Epoch 3/15
# Train Loss: 0.7253, Train Acc: 0.7996
# Val Loss: 0.6548, Val Acc: 0.7417
# Epoch 4/15
# Train Loss: 0.4865, Train Acc: 0.8764
# Val Loss: 0.5509, Val Acc: 0.7708
# Epoch 5/15
# Train Loss: 0.2849, Train Acc: 0.9522
# Val Loss: 0.4853, Val Acc: 0.8333
# Epoch 6/15
# Train Loss: 0.2011, Train Acc: 0.9616
# Val Loss: 0.4486, Val Acc: 0.8375
# Epoch 7/15
# Train Loss: 0.0836, Train Acc: 0.9948
# Val Loss: 0.4828, Val Acc: 0.8458
# Epoch 8/15
# Train Loss: 0.0595, Train Acc: 0.9979
# Val Loss: 0.5691, Val Acc: 0.8417
# Epoch 9/15
# Train Loss: 0.0884, Train Acc: 0.9855
# Val Loss: 0.5470, Val Acc: 0.8500
# Epoch 10/15
# Train Loss: 0.0554, Train Acc: 0.9875
# Val Loss: 0.5422, Val Acc: 0.8458
# Epoch 11/15
# Train Loss: 0.0239, Train Acc: 1.0000
# Val Loss: 0.5565, Val Acc: 0.8542
# Epoch 12/15
# Train Loss: 0.0255, Train Acc: 0.9958
# Val Loss: 0.6858, Val Acc: 0.8458
# Epoch 13/15
# Train Loss: 0.0393, Train Acc: 0.9938
# Val Loss: 0.4409, Val Acc: 0.8583
# Epoch 14/15
# Train Loss: 0.1802, Train Acc: 0.9553
# Val Loss: 0.6363, Val Acc: 0.7875
# Epoch 15/15
# Train Loss: 0.0828, Train Acc: 0.9865
# Val Loss: 0.5327, Val Acc: 0.8333
# Last Validation Accuracy for Fold 5: 0.8333
# Average Accuracy across all folds: 0.8802
# Best Validation Accuracy among all folds: 0.9421
# <All keys matched successfully>

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### Test 1

# %%
# Evaluate the model on the new test patient dataset
model.eval()
predicted_labels = []
true_labels = []

with torch.no_grad():
    for images, labels in test_loader_2:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        predicted_labels.extend(predicted.cpu().numpy())
        true_labels.extend(labels.cpu().numpy())


# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

accuracy_merged = np.trace(conf_matrix) / np.sum(conf_matrix)
# Print accuracy for merged classes
print(f"Accuracy : {accuracy_merged:.4f}")

# Display the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Good', 'Bad', 'Null'],
            yticklabels=['Good', 'Bad', 'Null'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy : 0.8305

# %%
# Compute precision, recall, and F1-score
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')

cls_report = classification_report(true_labels, predicted_labels, target_names=['Good', 'Bad', 'Null'])

print("Classification Report:")
print(cls_report)
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-Score: {f1:.4f}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.98      0.93      0.95        45
#          Bad       0.70      0.61      0.66        31
#         Null       0.77      0.88      0.82        42
#
#     accuracy                           0.83       118
#    macro avg       0.82      0.81      0.81       118
# weighted avg       0.83      0.83      0.83       118
#
# Precision: 0.8317
# Recall: 0.8305
# F1-Score: 0.8288

# %% [markdown]
# #### Test 2

# %%
# Evaluate the model on the new test patient dataset
model.eval()
predicted_labels = []
true_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        predicted_labels.extend(predicted.cpu().numpy())
        true_labels.extend(labels.cpu().numpy())


# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

accuracy_merged = np.trace(conf_matrix) / np.sum(conf_matrix)
# Print accuracy for merged classes
print(f"Accuracy : {accuracy_merged:.4f}")

# Display the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Good', 'Bad', 'Null'],
            yticklabels=['Good', 'Bad', 'Null'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy : 0.8342

# %%
# Compute precision, recall, and F1-score
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')

cls_report = classification_report(true_labels, predicted_labels, target_names=['Good', 'Bad', 'Null'])

print("Classification Report:")
print(cls_report)
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-Score: {f1:.4f}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       1.00      0.90      0.95        88
#          Bad       0.42      0.67      0.52        24
#         Null       0.87      0.81      0.84        81
#
#     accuracy                           0.83       193
#    macro avg       0.76      0.79      0.77       193
# weighted avg       0.87      0.83      0.85       193
#
# Precision: 0.8728
# Recall: 0.8342
# F1-Score: 0.8484
