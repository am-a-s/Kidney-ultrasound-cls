# %% [markdown]
# ### Import

# %%
import os
import random
import numpy as np
import collections
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import GroupKFold
from PIL import Image
import re
from torchvision import transforms, models
import copy
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Difine Seed

# %%
# Set a fixed seed value for reproducibility
seed = 42

# Set the seed for Python's built-in random module
random.seed(seed)

# Set the seed for NumPy
np.random.seed(seed)

# Set the seed for PyTorch
torch.manual_seed(seed)

# Ensure that the seed is set for CUDA as well if using GPU
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if using multi-GPU

# Additional configuration for determinism
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Data Utils

# %%
class CustomDataset(Dataset):
    def __init__(self, file_paths, labels, transform=None):
        self.file_paths = file_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        file_path = self.file_paths[idx]

        image = Image.open(file_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        label = self.labels[idx]
        return image, label

# Function to extract patient ID from filenames (for k-fold cross validation)
def extract_patient_id(filename):
    match = re.match(r'([\w\s]+-\d+of\d+)', filename)
    if match:
        return match.group(1)
    else:
        raise ValueError(f"Filename {filename} does not match the expected pattern.")

# Function to load data and split into file paths, labels, and patient IDs
def load_data(root_dir, classes):
    file_paths = []
    labels = []
    patient_ids = []

    for class_index, class_name in enumerate(classes):
        class_dir = os.path.join(root_dir, class_name)
        for filename in os.listdir(class_dir):
            file_path = os.path.join(class_dir, filename)
            file_paths.append(file_path)
            labels.append(class_index)
            patient_ids.append(extract_patient_id(filename))

    return file_paths, labels, patient_ids

# Define transform
transform = transforms.Compose([
    transforms.Resize((240, 240)),
    transforms.ToTensor(),
])

# %%
# Define root directory and classes
root_dir = "/content/drive/MyDrive/projects/SecondTry/JPG_480/train"
test_root_dir = "/content/drive/MyDrive/projects/SecondTry/JPG_480/test"
test_root_dir_2 = "/content/drive/MyDrive/projects/SecondTry/JPG_480/val"
classes = ['Good', 'Bad', 'Null']

# Load file paths, labels, and patient IDs
file_paths, labels, patient_ids = load_data(root_dir, classes)
test_file_paths, test_labels, test_patient_ids = load_data(test_root_dir, classes)
test_file_paths_2, test_labels_2, test_patient_ids_2 = load_data(test_root_dir_2, classes)

# %%
# Create a test dataset
test_dataset = CustomDataset(test_file_paths, test_labels, transform=transform)
test_dataset_2 = CustomDataset(test_file_paths_2, test_labels_2, transform=transform)

# Create a DataLoader for the test dataset
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
test_loader_2 = DataLoader(test_dataset_2, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ### K-Fold

# %%
# Initialize GroupKFold
num_folds = 5
gkf = GroupKFold(n_splits=num_folds)

# %% [markdown]
# ### Model

# %%
class ModifiedResNet50(nn.Module):
    def __init__(self, num_classes, dropout_prob=0.6):
        super(ModifiedResNet50, self).__init__()
        self.resnet = models.resnet50(pretrained=True)
        num_features = self.resnet.fc.in_features
        self.resnet.fc = nn.Sequential(
            nn.Dropout(p=dropout_prob),
            nn.Linear(num_features, num_classes)
        )

    def forward(self, x):
        return self.resnet(x)

# %% [markdown]
# ### Hyperparameter

# %%
fold_results = []  # To store the last validation accuracy of each fold
best_model_per_fold = None  # To store the best model based on the last validation accuracy
best_fold_acc = 0.0  # Track the highest validation accuracy among the last epochs of all folds

num_epochs = 15

# Total number of unique patients across the dataset
total_unique_patients = len(set(patient_ids))

# Define the number of classes
num_classes = len(classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Train Utils

# %%
# Function to train the model for a single epoch
def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        _, preds = torch.max(outputs, 1)
        correct += torch.sum(preds == labels.data)
    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = correct.double() / len(dataloader.dataset)
    return epoch_loss, epoch_acc

# Function to validate the model
def validate_one_epoch(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += torch.sum(preds == labels.data)
    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = correct.double() / len(dataloader.dataset)
    return epoch_loss, epoch_acc

# %% [markdown]
# ### Training

# %%
for fold, (train_idx, val_idx) in enumerate(gkf.split(file_paths, labels, groups=patient_ids)):
    print(f'Fold {fold+1}/{num_folds}')

    # Get patient IDs for training and validation sets
    train_patient_ids = [patient_ids[i] for i in train_idx]
    val_patient_ids = [patient_ids[i] for i in val_idx]

    # Check for overlap between training and validation patient IDs
    overlap = set(train_patient_ids) & set(val_patient_ids)
    if overlap:
        print(f"Overlap detected in fold {fold+1}! Overlapping patient IDs: {overlap}")
    else:
        print(f"No overlap between training and validation patient sets in fold {fold+1}.")

    # Calculate the percentage of unique patients in the validation set
    unique_val_patients = len(set(val_patient_ids))
    val_percentage = (unique_val_patients / total_unique_patients) * 100
    print(f'Percentage of patients in validation set for fold {fold+1}: {val_percentage:.2f}%')

    # Create training and validation datasets for this fold
    train_dataset = CustomDataset([file_paths[i] for i in train_idx], [labels[i] for i in train_idx], transform=transform)
    val_dataset = CustomDataset([file_paths[i] for i in val_idx], [labels[i] for i in val_idx], transform=transform)

    # Create dataloaders
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

    # Initialize the model for this fold (reinitialize weights)
    model = ModifiedResNet50(num_classes=num_classes, dropout_prob=0.5)
    model = model.to(device)

    # Define optimizer and loss function
    optimizer = optim.SGD(model.parameters(), lr=0.000714, momentum=0.9)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')

        # Train and validate for one epoch
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_loss, val_acc = validate_one_epoch(model, val_loader, criterion, device)

        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')
        print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

    # Save the last validation accuracy of the current fold
    fold_results.append(val_acc.item())

    print(f'Last Validation Accuracy for Fold {fold+1}: {val_acc:.4f}')

    # Track the best model and accuracy among the last validation accuracies
    if val_acc > best_fold_acc:
        best_fold_acc = val_acc
        best_model_per_fold = copy.deepcopy(model.state_dict())  # Store the best model weights

# Calculate the average accuracy across all folds
average_acc = sum(fold_results) / len(fold_results)
print(f'Average Accuracy across all folds: {average_acc:.4f}')

# Print the best validation accuracy among the last validation accuracies
print(f'Best Validation Accuracy among all folds: {best_fold_acc:.4f}')

# Load the best model weights from the fold with the highest last validation accuracy
model.load_state_dict(best_model_per_fold)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Fold 1/5
# No overlap between training and validation patient sets in fold 1.
# Percentage of patients in validation set for fold 1: 20.25%
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 153MB/s]
# Epoch 1/15
# Train Loss: 1.0200, Train Acc: 0.4823
# Val Loss: 0.9898, Val Acc: 0.5436
# Epoch 2/15
# Train Loss: 0.5937, Train Acc: 0.7547
# Val Loss: 0.5766, Val Acc: 0.7510
# Epoch 3/15
# Train Loss: 0.2947, Train Acc: 0.9148
# Val Loss: 0.4359, Val Acc: 0.8257
# Epoch 4/15
# Train Loss: 0.1558, Train Acc: 0.9615
# Val Loss: 0.3716, Val Acc: 0.8382
# Epoch 5/15
# Train Loss: 0.1014, Train Acc: 0.9834
# Val Loss: 0.3256, Val Acc: 0.8755
# Epoch 6/15
# Train Loss: 0.0554, Train Acc: 0.9896
# Val Loss: 0.2913, Val Acc: 0.8921
# Epoch 7/15
# Train Loss: 0.0744, Train Acc: 0.9844
# Val Loss: 0.2668, Val Acc: 0.9129
# Epoch 8/15
# Train Loss: 0.0394, Train Acc: 0.9917
# Val Loss: 0.2907, Val Acc: 0.8963
# Epoch 9/15
# Train Loss: 0.0337, Train Acc: 0.9927
# Val Loss: 0.2420, Val Acc: 0.9378
# Epoch 10/15
# Train Loss: 0.0310, Train Acc: 0.9958
# Val Loss: 0.2948, Val Acc: 0.9046
# Epoch 11/15
# Train Loss: 0.0157, Train Acc: 0.9979
# Val Loss: 0.2812, Val Acc: 0.9087
# Epoch 12/15
# Train Loss: 0.0334, Train Acc: 0.9948
# Val Loss: 0.2966, Val Acc: 0.8672
# Epoch 13/15
# Train Loss: 0.0177, Train Acc: 0.9958
# Val Loss: 0.2516, Val Acc: 0.9046
# Epoch 14/15
# Train Loss: 0.0158, Train Acc: 0.9969
# Val Loss: 0.2855, Val Acc: 0.8880
# Epoch 15/15
# Train Loss: 0.0293, Train Acc: 0.9906
# Val Loss: 0.2607, Val Acc: 0.9046
# Last Validation Accuracy for Fold 1: 0.9046
# Fold 2/5
# No overlap between training and validation patient sets in fold 2.
# Percentage of patients in validation set for fold 2: 19.63%
# Epoch 1/15
# Train Loss: 1.0177, Train Acc: 0.4995
# Val Loss: 0.9559, Val Acc: 0.5667
# Epoch 2/15
# Train Loss: 0.5585, Train Acc: 0.8152
# Val Loss: 0.5492, Val Acc: 0.7625
# Epoch 3/15
# Train Loss: 0.2866, Train Acc: 0.9283
# Val Loss: 0.3787, Val Acc: 0.8583
# Epoch 4/15
# Train Loss: 0.1647, Train Acc: 0.9751
# Val Loss: 0.3659, Val Acc: 0.8125
# Epoch 5/15
# Train Loss: 0.0763, Train Acc: 0.9907
# Val Loss: 0.3692, Val Acc: 0.8625
# Epoch 6/15
# Train Loss: 0.0549, Train Acc: 0.9938
# Val Loss: 0.3419, Val Acc: 0.8417
# Epoch 7/15
# Train Loss: 0.0482, Train Acc: 0.9938
# Val Loss: 0.3423, Val Acc: 0.8417
# Epoch 8/15
# Train Loss: 0.0294, Train Acc: 0.9979
# Val Loss: 0.3494, Val Acc: 0.8583
# Epoch 9/15
# Train Loss: 0.0271, Train Acc: 0.9969
# Val Loss: 0.4544, Val Acc: 0.8458
# Epoch 10/15
# Train Loss: 0.0212, Train Acc: 0.9979
# Val Loss: 0.3674, Val Acc: 0.8583
# Epoch 11/15
# Train Loss: 0.0393, Train Acc: 0.9927
# Val Loss: 0.4412, Val Acc: 0.7958
# Epoch 12/15
# Train Loss: 0.0417, Train Acc: 0.9865
# Val Loss: 0.5213, Val Acc: 0.8125
# Epoch 13/15
# Train Loss: 0.0474, Train Acc: 0.9865
# Val Loss: 0.4171, Val Acc: 0.8083
# Epoch 14/15
# Train Loss: 0.0536, Train Acc: 0.9855
# Val Loss: 0.3887, Val Acc: 0.8458
# Epoch 15/15
# Train Loss: 0.0549, Train Acc: 0.9834
# Val Loss: 0.3979, Val Acc: 0.8167
# Last Validation Accuracy for Fold 2: 0.8167
# Fold 3/5
# No overlap between training and validation patient sets in fold 3.
# Percentage of patients in validation set for fold 3: 20.25%
# Epoch 1/15
# Train Loss: 1.0309, Train Acc: 0.4735
# Val Loss: 1.0039, Val Acc: 0.4421
# Epoch 2/15
# Train Loss: 0.5838, Train Acc: 0.7711
# Val Loss: 0.7781, Val Acc: 0.6281
# Epoch 3/15
# Train Loss: 0.3139, Train Acc: 0.9116
# Val Loss: 0.3143, Val Acc: 0.8967
# Epoch 4/15
# Train Loss: 0.1409, Train Acc: 0.9698
# Val Loss: 0.2571, Val Acc: 0.9008
# Epoch 5/15
# Train Loss: 0.0735, Train Acc: 0.9906
# Val Loss: 0.2392, Val Acc: 0.9339
# Epoch 6/15
# Train Loss: 0.0418, Train Acc: 0.9979
# Val Loss: 0.3108, Val Acc: 0.8760
# Epoch 7/15
# Train Loss: 0.0423, Train Acc: 0.9917
# Val Loss: 0.2674, Val Acc: 0.9091
# Epoch 8/15
# Train Loss: 0.0497, Train Acc: 0.9865
# Val Loss: 0.3003, Val Acc: 0.9050
# Epoch 9/15
# Train Loss: 0.0202, Train Acc: 0.9979
# Val Loss: 0.3584, Val Acc: 0.8884
# Epoch 10/15
# Train Loss: 0.0431, Train Acc: 0.9865
# Val Loss: 0.4088, Val Acc: 0.8719
# Epoch 11/15
# Train Loss: 0.0357, Train Acc: 0.9917
# Val Loss: 0.3724, Val Acc: 0.8967
# Epoch 12/15
# Train Loss: 0.0244, Train Acc: 0.9938
# Val Loss: 0.2672, Val Acc: 0.9008
# Epoch 13/15
# Train Loss: 0.0241, Train Acc: 0.9969
# Val Loss: 0.4256, Val Acc: 0.8595
# Epoch 14/15
# Train Loss: 0.0226, Train Acc: 0.9927
# Val Loss: 0.2974, Val Acc: 0.9298
# Epoch 15/15
# Train Loss: 0.0215, Train Acc: 0.9917
# Val Loss: 0.3507, Val Acc: 0.9008
# Last Validation Accuracy for Fold 3: 0.9008
# Fold 4/5
# No overlap between training and validation patient sets in fold 4.
# Percentage of patients in validation set for fold 4: 19.63%
# Epoch 1/15
# Train Loss: 1.0088, Train Acc: 0.4933
# Val Loss: 0.9836, Val Acc: 0.4958
# Epoch 2/15
# Train Loss: 0.5400, Train Acc: 0.8307
# Val Loss: 0.7802, Val Acc: 0.5917
# Epoch 3/15
# Train Loss: 0.2812, Train Acc: 0.9211
# Val Loss: 0.4564, Val Acc: 0.8167
# Epoch 4/15
# Train Loss: 0.1682, Train Acc: 0.9637
# Val Loss: 0.4249, Val Acc: 0.8292
# Epoch 5/15
# Train Loss: 0.1083, Train Acc: 0.9772
# Val Loss: 0.3934, Val Acc: 0.8417
# Epoch 6/15
# Train Loss: 0.0494, Train Acc: 0.9958
# Val Loss: 0.4782, Val Acc: 0.8167
# Epoch 7/15
# Train Loss: 0.0341, Train Acc: 0.9958
# Val Loss: 0.4730, Val Acc: 0.8375
# Epoch 8/15
# Train Loss: 0.0459, Train Acc: 0.9907
# Val Loss: 0.5556, Val Acc: 0.7917
# Epoch 9/15
# Train Loss: 0.0261, Train Acc: 0.9958
# Val Loss: 0.3773, Val Acc: 0.8500
# Epoch 10/15
# Train Loss: 0.0254, Train Acc: 0.9969
# Val Loss: 0.3588, Val Acc: 0.8500
# Epoch 11/15
# Train Loss: 0.1109, Train Acc: 0.9688
# Val Loss: 0.3931, Val Acc: 0.8292
# Epoch 12/15
# Train Loss: 0.0369, Train Acc: 0.9958
# Val Loss: 0.4106, Val Acc: 0.8667
# Epoch 13/15
# Train Loss: 0.0682, Train Acc: 0.9792
# Val Loss: 0.3019, Val Acc: 0.8750
# Epoch 14/15
# Train Loss: 0.0299, Train Acc: 0.9938
# Val Loss: 0.4020, Val Acc: 0.8875
# Epoch 15/15
# Train Loss: 0.0176, Train Acc: 0.9958
# Val Loss: 0.5705, Val Acc: 0.8417
# Last Validation Accuracy for Fold 4: 0.8417
# Fold 5/5
# No overlap between training and validation patient sets in fold 5.
# Percentage of patients in validation set for fold 5: 20.25%
# Epoch 1/15
# Train Loss: 0.9907, Train Acc: 0.5036
# Val Loss: 0.9251, Val Acc: 0.6167
# Epoch 2/15
# Train Loss: 0.5621, Train Acc: 0.7975
# Val Loss: 0.5425, Val Acc: 0.8042
# Epoch 3/15
# Train Loss: 0.2602, Train Acc: 0.9450
# Val Loss: 0.3987, Val Acc: 0.8375
# Epoch 4/15
# Train Loss: 0.1460, Train Acc: 0.9730
# Val Loss: 0.4263, Val Acc: 0.8083
# Epoch 5/15
# Train Loss: 0.0823, Train Acc: 0.9896
# Val Loss: 0.4278, Val Acc: 0.8458
# Epoch 6/15
# Train Loss: 0.0376, Train Acc: 0.9969
# Val Loss: 0.3512, Val Acc: 0.8750
# Epoch 7/15
# Train Loss: 0.0285, Train Acc: 0.9958
# Val Loss: 0.3520, Val Acc: 0.8833
# Epoch 8/15
# Train Loss: 0.0658, Train Acc: 0.9844
# Val Loss: 0.4564, Val Acc: 0.8208
# Epoch 9/15
# Train Loss: 0.0616, Train Acc: 0.9927
# Val Loss: 0.4297, Val Acc: 0.8583
# Epoch 10/15
# Train Loss: 0.0294, Train Acc: 0.9958
# Val Loss: 0.4942, Val Acc: 0.8417
# Epoch 11/15
# Train Loss: 0.0194, Train Acc: 0.9969
# Val Loss: 0.4130, Val Acc: 0.8750
# Epoch 12/15
# Train Loss: 0.0122, Train Acc: 1.0000
# Val Loss: 0.4466, Val Acc: 0.8708
# Epoch 13/15
# Train Loss: 0.0133, Train Acc: 0.9979
# Val Loss: 0.4348, Val Acc: 0.8708
# Epoch 14/15
# Train Loss: 0.0200, Train Acc: 0.9948
# Val Loss: 0.3598, Val Acc: 0.8833
# Epoch 15/15
# Train Loss: 0.0089, Train Acc: 0.9990
# Val Loss: 0.4455, Val Acc: 0.8667
# Last Validation Accuracy for Fold 5: 0.8667
# Average Accuracy across all folds: 0.8661
# Best Validation Accuracy among all folds: 0.9046
# <All keys matched successfully>

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### Test 1

# %%
# Evaluate the model on the new test patient dataset
model.eval()
predicted_labels = []
true_labels = []

with torch.no_grad():
    for images, labels in test_loader_2:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        predicted_labels.extend(predicted.cpu().numpy())
        true_labels.extend(labels.cpu().numpy())


# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

accuracy_merged = np.trace(conf_matrix) / np.sum(conf_matrix)
# Print accuracy for merged classes
print(f"Accuracy : {accuracy_merged:.4f}")

# Display the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Good', 'Bad', 'Null'],
            yticklabels=['Good', 'Bad', 'Null'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Accuracy : 0.8136

# %%
# Compute precision, recall, and F1-score
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')

cls_report = classification_report(true_labels, predicted_labels, target_names=['Good', 'Bad', 'Null'])

print("Classification Report:")
print(cls_report)
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-Score: {f1:.4f}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       1.00      0.93      0.97        45
#          Bad       0.86      0.39      0.53        31
#         Null       0.68      1.00      0.81        42
#
#     accuracy                           0.81       118
#    macro avg       0.84      0.77      0.77       118
# weighted avg       0.85      0.81      0.80       118
#
# Precision: 0.8477
# Recall: 0.8136
# F1-Score: 0.7958

# %% [markdown]
# #### Teat 2

# %%
# Evaluate the model on the new test patient dataset
model.eval()
predicted_labels = []
true_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        predicted_labels.extend(predicted.cpu().numpy())
        true_labels.extend(labels.cpu().numpy())


# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

accuracy_merged = np.trace(conf_matrix) / np.sum(conf_matrix)
# Print accuracy for merged classes
print(f"Accuracy : {accuracy_merged:.4f}")

# Display the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Good', 'Bad', 'Null'],
            yticklabels=['Good', 'Bad', 'Null'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Accuracy : 0.8135

# %%
# Compute precision, recall, and F1-score
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')

cls_report = classification_report(true_labels, predicted_labels, target_names=['Good', 'Bad', 'Null'])

print("Classification Report:")
print(cls_report)
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-Score: {f1:.4f}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.90      0.97      0.93        88
#          Bad       0.42      0.33      0.37        24
#         Null       0.80      0.79      0.80        81
#
#     accuracy                           0.81       193
#    macro avg       0.71      0.70      0.70       193
# weighted avg       0.80      0.81      0.81       193
#
# Precision: 0.8004
# Recall: 0.8135
# F1-Score: 0.8058
